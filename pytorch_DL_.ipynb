# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushi-006/pytorch/blob/main/pytorch_DL_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ## Why not use Pure Python?
#  * List in Python is in fact Linked list.
#  * Performing multidimension computaion is not possible due to Python GIL (Global Interpreter Lock)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Frameworks like Numpy dont have GPU specification

# %% [markdown]
# | component | Description |
# |----------|----------|
# |`torch`    | A tensor library like Numpy with strong GPU support|
# | `torch.autograd`   | A diffrentiable library that supports all diffrentiable Tensor operations in Torch     |
# | `torch.jit`| A compilation Stack(TorchScript) to create a serializable and optimizable models from PyTorch code     |
# | `torch.nn`   | A NN library deeply integrated with autograd designed for maximum flexibility      |
# | `torch.multiprocessing`   | Magical memory sharing of torch Tensors across processors. Useful for data loading and Hogwild training     |
# |   `torch.utils`  | Data loader and other utility functions for convience    |
